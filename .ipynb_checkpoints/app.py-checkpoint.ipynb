# %%
#Install muna ito
# !pip install ultralytics --user

# %%
#then ito
#dapat nvidia gpu and version 12.9 ang cuda
#adjust code kung iba version ng cuda
#kapag hindi nvidia gpu, i-gpt na lang kung paano ilipat from GPU to CPU
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version used by PyTorch: {torch.version.cuda}")
print(f"Number of GPUs: {torch.cuda.device_count()}")

if torch.cuda.is_available():
    print(f"Current GPU: {torch.cuda.get_device_name(0)}")
    
    # Test CUDA
    x = torch.rand(5, 3)
    print(f"\nTensor on CPU: {x}")
    
    x = x.cuda()
    print(f"Tensor on GPU: {x}")
    print(f"Is tensor on CUDA? {x.is_cuda}")

# %%
pip install filterpy

# %%
#kapag okay na sa setup and install, I-run muna ito para maload ang model
import os

# Your model path
MODEL_PATH = r"E:\0Index\New folder\Zero Index Capstone Project Front End\assets\model\best.pt"

# Verify the file exists
if os.path.exists(MODEL_PATH):
    print(f"✓ Model found at: {MODEL_PATH}")
    print(f"File size: {os.path.getsize(MODEL_PATH) / 1024 / 1024:.2f} MB")
else:
    print(f"✗ Model not found at: {MODEL_PATH}")
    print("Please check the path and try again")

# %%
import sys
# Install numpy first
# !{sys.executable} -m pip install numpy==1.23.5

# Then install the rest
# !{sys.executable} -m pip install pandas==1.5.3
# !{sys.executable} -m pip install scipy==1.10.1  
# !{sys.executable} -m pip install scikit-learn==1.3.0
# !{sys.executable} -m pip install xgboost==1.7.6
# Out:
# ...
#   Using cached numpy-1.23.5-cp310-cp310-win_amd64.whl (14.6 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.3.167 requires pandas>=1.1.4, which is not installed.
# xarray 2022.11.0 requires pandas>=1.3, which is not installed.
# statsmodels 0.13.5 requires pandas>=0.25, which is not installed.
# seaborn 0.12.2 requires pandas>=0.25, which is not installed.
# imbalanced-learn 0.10.1 requires scikit-learn>=1.0.2, which is not installed.
# hvplot 0.8.2 requires pandas, which is not installed.
# holoviews 1.15.4 requires pandas>=0.20.0, which is not installed.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# datashader 0.14.4 requires pandas, which is not installed.
# daal4py 2023.0.2 requires scikit-learn>=0.24, which is not installed.
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import torch
from flask_cors import CORS
from flask import Flask, request, jsonify
from ultralytics import YOLO
import cv2
import numpy as np
import json
from xgboost import XGBRegressor
from datetime import datetime
import traceback
from shapely.geometry import Polygon, Point
from collections import defaultdict, deque
import importlib.util
import csv
from pathlib import Path
from datetime import datetime, timedelta

# Add the path where detect.py is located
detect_path = detect_path = os.getenv("detect_path", "/detect.py")
if detect_path not in sys.path:
    sys.path.append(detect_path)

# Import from detect.py
from detect import zone_definitions

from sort import Sort, KalmanBoxTracker

# Your model path
MODEL_PATH = os.getenv("MODEL_PATH", "assets/model/best.pt")

class SubwayDetectionServer:
    def __init__(self, model_path):
        # Reset the global tracker ID counter on server initialization
        KalmanBoxTracker.count = 0
        self.app = Flask(__name__)
        CORS(self.app)
        self.model_path = model_path
        self.model = None
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
        self.timestamp_override = None
        self.timestamp_offset = None 

        self.xgboost_model = None
        self.xgboost_features = None
        self.xgboost_config = None
        self.max_capacity = 40
        self.xgboost_model_path = "passenger_model.json"
        self.xgboost_features_path = "feature_columns.json"
        self.xgboost_config_path = "model_config.json"

        self.load_xgboost_model()
        
        # ✅ Store passenger count history for feature calculation
        self.passenger_count_history = deque(maxlen=180)
        self.detection_history_buffer = deque(maxlen=180)
        
        # ✅ NEW: Store real-time predictions for video processing
        self.video_predictions = []
        self.last_prediction_time = None
        self.prediction_interval = 10.0  # Predict every 10 seconds
        
        # Train detection state
        self.train_present = False
        self.train_detection_threshold = 0.5
        self.last_train_detection_time = None
        self.train_absence_timeout = 3.0
        self.train_bboxes = []
        
        # CSV logging
        self.csv_log_dir = Path(r"C:\0Index\CSV_LOG")   
        self.csv_log_dir.mkdir(parents=True, exist_ok=True)
        
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        self.detection_log_csv = self.csv_log_dir / f"detection_log_{timestamp}.csv"
        self.init_detection_log_csv()
        self.last_log_time = None
        self.log_interval = 10.0
        
        # Peak hours definition
        self.peak_hours = [(6, 9), (17, 20)]
        
        # Use zones from detect.py
        self.zone_definitions = zone_definitions
        
        # Initialize SORT trackers for each camera
        self.trackers = {
            "cam1": Sort(max_age=90, min_hits=1, iou_threshold=0.2),
            "cam2": Sort(max_age=120, min_hits=1, iou_threshold=0.2),
            "cam3": Sort(max_age=90, min_hits=1, iou_threshold=0.2)
        }
        
        # Track person histories and breach status
        self.person_histories = defaultdict(lambda: {
            "positions": [],
            "breach_history": [],
            "first_seen": None,
            "last_seen": None,
            "total_breaches": {"warning": 0, "danger": 0}
        })
        
        # Statistics
        self.stats = {
            "total_detections": 0,
            "danger_breaches": 0,
            "warning_breaches": 0,
            "breach_logs": [],
            "unique_people": set()
        }
        
        print(f"Using device: {self.device}")
        if self.device == 'cuda':
            print(f"GPU: {torch.cuda.get_device_name(0)}")
            print(f"CUDA version: {torch.version.cuda}")
        
        self.load_model()
        self.setup_routes()
    
    def load_model(self):
        if not os.path.exists(self.model_path):
            raise FileNotFoundError(f"Model not found at: {self.model_path}")
        
        try:
            print(f"Loading model from: {self.model_path}")
            self.model = YOLO(self.model_path)
            self.model.to(self.device)
            
            dummy_img = np.zeros((640, 640, 3), dtype=np.uint8)
            with torch.no_grad():
                _ = self.model(dummy_img)
            
            print(f"✓ Model loaded successfully on {self.device}")
        except Exception as e:
            print(f"✗ Error loading model: {e}")
            traceback.print_exc()
            raise
    
    def load_xgboost_model(self):
        try:
            model_exists = os.path.exists(self.xgboost_model_path)
            features_exist = os.path.exists(self.xgboost_features_path)
            config_exists = os.path.exists(self.xgboost_config_path)
            
            if model_exists and features_exist:
                self.xgboost_model = XGBRegressor()
                self.xgboost_model.load_model(self.xgboost_model_path)
                
                with open(self.xgboost_features_path, 'r') as f:
                    self.xgboost_features = json.load(f)
                
                if config_exists:
                    with open(self.xgboost_config_path, 'r') as f:
                        self.xgboost_config = json.load(f)
                        self.max_capacity = self.xgboost_config.get('max_capacity', 40)
                
                print("="*60)
                print("✅ XGBoost MODEL LOADED SUCCESSFULLY")
                print("="*60)
                print(f"   Model: {self.xgboost_model_path}")
                print(f"   Features: {len(self.xgboost_features)}")
                print(f"   Max Capacity: {self.max_capacity}")
                if self.xgboost_config:
                    print(f"   Model R² Score: {self.xgboost_config.get('test_r2_score', 'N/A')}")
                    print(f"   Training Date: {self.xgboost_config.get('training_date', 'N/A')}")
                print(f"   🎯 CROWDING PREDICTION: ENABLED")
                print("="*60)
                return True
            else:
                print("="*60)
                print("⚠️ XGBOOST MODEL NOT FOUND")
                print("="*60)
                print("   Crowding prediction: DISABLED")
                print("   Server will run in data collection mode only.")
                print("="*60)
                return False
                
        except Exception as e:
            print(f"❌ Error loading XGBoost model: {e}")
            traceback.print_exc()
            return False
    
    def classify_crowding_level(self, percentage, passenger_count):
        over_capacity = max(0, passenger_count - self.max_capacity)
        
        if percentage <= 30:
            return {
                "level": "Low",
                "emoji": "🟢",
                "color": "#06D6A0",
                "priority": 1,
                "recommendation": "✅ Normal operations. Comfortable passenger load.",
                "action_required": False,
                "over_capacity": 0
            }
        elif percentage <= 60:
            return {
                "level": "Moderate",
                "emoji": "🟡",
                "color": "#FFD166",
                "priority": 2,
                "recommendation": "⚠️ Alert staff. Monitor traffic closely.",
                "action_required": False,
                "over_capacity": 0
            }
        elif percentage <= 90:
            return {
                "level": "High",
                "emoji": "🟠",
                "color": "#F77F00",
                "priority": 3,
                "recommendation": "⚠️ HIGH ALERT: Approaching capacity. Deploy staff.",
                "action_required": True,
                "over_capacity": 0
            }
        elif percentage <= 100:
            return {
                "level": "Critical",
                "emoji": "🔴",
                "color": "#EF476F",
                "priority": 4,
                "recommendation": "🚨 CRITICAL: At full capacity. Implement crowd control.",
                "action_required": True,
                "over_capacity": 0
            }
        else:
            return {
                "level": "OVERCROWDED",
                "emoji": "🚨",
                "color": "#C1121F",
                "priority": 5,
                "recommendation": f"🚨🚨 EMERGENCY: OVERCROWDED by {int(over_capacity)} people! STOP ENTRY NOW!",
                "action_required": True,
                "over_capacity": int(over_capacity)
            }
    
    def predict_crowding(self, timestamp=None, passenger_count=None):
        """
        Predict crowding with optional override for current passenger count
        This allows prediction during video processing with exact detected counts
        """
        if self.xgboost_model is None:
            return None
        
        try:
            if timestamp is None:
                timestamp = self.get_current_timestamp()
            
            # Use provided passenger count or get from history
            if passenger_count is None:
                if len(self.passenger_count_history) == 0:
                    return None
                current_passenger_count = self.passenger_count_history[-1]
            else:
                current_passenger_count = passenger_count
                # Add to history if it's new data
                if len(self.passenger_count_history) == 0 or current_passenger_count != self.passenger_count_history[-1]:
                    self.passenger_count_history.append(current_passenger_count)
            
            # Calculate all features
            features = self.calculate_features(current_passenger_count, timestamp)
            
            # Create feature vector
            feature_vector = []
            for feat_name in self.xgboost_features:
                if feat_name in features:
                    feature_vector.append(features[feat_name])
                elif feat_name == 'passenger_count':
                    feature_vector.append(current_passenger_count)
                elif feat_name == 'hour':
                    feature_vector.append(timestamp.hour)
                elif feat_name == 'minute':
                    feature_vector.append(timestamp.minute)
                elif feat_name == 'day_of_week':
                    feature_vector.append(timestamp.weekday())
                else:
                    feature_vector.append(0)
            
            # Make prediction
            X = np.array([feature_vector])
            predicted_count = float(self.xgboost_model.predict(X)[0])
            predicted_count = max(0, predicted_count)
            
            # Calculate percentage
            predicted_percentage = (predicted_count / self.max_capacity) * 100
            current_percentage = (current_passenger_count / self.max_capacity) * 100
            
            # Get classification for both current and predicted
            current_classification = self.classify_crowding_level(current_percentage, current_passenger_count)
            predicted_classification = self.classify_crowding_level(predicted_percentage, predicted_count)
            
            result = {
                "success": True,
                "timestamp": timestamp.isoformat(),
                "current": {
                    "count": int(current_passenger_count),
                    "percentage": round(current_percentage, 2),
                    "level": current_classification["level"],
                    "emoji": current_classification["emoji"],
                    "color": current_classification["color"]
                },
                "predicted": {
                    "count": round(predicted_count, 1),
                    "percentage": round(predicted_percentage, 2),
                    "level": predicted_classification["level"],
                    "emoji": predicted_classification["emoji"],
                    "color": predicted_classification["color"],
                    "priority": predicted_classification["priority"],
                    "recommendation": predicted_classification["recommendation"],
                    "action_required": predicted_classification["action_required"],
                    "over_capacity": predicted_classification["over_capacity"]
                },
                "max_capacity": self.max_capacity,
                "trend": "increasing" if predicted_count > current_passenger_count else "decreasing" if predicted_count < current_passenger_count else "stable"
            }
            
            # Add safety alert if predicted overcrowding
            if predicted_classification["level"] == "OVERCROWDED":
                result["safety_alert"] = {
                    "type": "PREDICTED_OVERCROWDING",
                    "severity": "WARNING",
                    "message": f"Predicted overcrowding: {predicted_classification['over_capacity']} over capacity",
                    "actions": [
                        "Prepare crowd control measures",
                        "Alert security staff",
                        "Monitor entry points closely",
                        "Consider restricting platform access"
                    ]
                }
            
            return result
            
        except Exception as e:
            print(f"[ERROR] Crowding prediction failed: {e}")
            traceback.print_exc()
            return {
                "success": False,
                "error": str(e)
            }
    
    # ============================================================================
    # ✅ NEW: REAL-TIME PREDICTION DURING VIDEO PROCESSING
    # ============================================================================
    
    def should_make_prediction(self, current_time):
        """Check if enough time has passed to make a new prediction"""
        if self.last_prediction_time is None:
            return True
        
        time_diff = (current_time - self.last_prediction_time).total_seconds()
        return time_diff >= self.prediction_interval
    
    def make_video_prediction(self, passenger_count, timestamp, frame_id):
        """
        Make a prediction during video processing and store it
        Returns the prediction result
        """
        if self.xgboost_model is None:
            return None
        
        # Check if we should make a prediction (every 10 seconds)
        if not self.should_make_prediction(timestamp):
            return None
        
        # Make prediction with current passenger count
        prediction = self.predict_crowding(timestamp, passenger_count)
        
        if prediction and prediction.get('success'):
            # Add frame information
            prediction['frame_id'] = frame_id
            prediction['video_time'] = timestamp.strftime("%H:%M:%S")
            
            # Store prediction
            self.video_predictions.append(prediction)
            self.last_prediction_time = timestamp
            
            # Print real-time prediction info
            current = prediction['current']
            predicted = prediction['predicted']
            print(f"[PREDICTION] Frame {frame_id} | Time: {prediction['video_time']}")
            print(f"  Current: {current['count']} ({current['percentage']:.1f}%) {current['emoji']} {current['level']}")
            print(f"  Predicted: {predicted['count']:.1f} ({predicted['percentage']:.1f}%) {predicted['emoji']} {predicted['level']}")
            print(f"  Trend: {prediction['trend']}")
            
            if 'safety_alert' in prediction:
                print(f"  ⚠️ ALERT: {prediction['safety_alert']['message']}")
            print("")
            
            return prediction
        
        return None
    
    def get_latest_prediction(self):
        """Get the most recent prediction made during video processing"""
        if len(self.video_predictions) > 0:
            return self.video_predictions[-1]
        return None
    
    def clear_video_predictions(self):
        """Clear stored predictions (call at start of new video)"""
        self.video_predictions = []
        self.last_prediction_time = None
    
    # ============================================================================
    
    def detect_train(self, image):
        """Detect train in the image using YOLO model"""
        try:
            results = self.model.predict(source=image, conf=0.3, save=False, verbose=False)
            
            train_detected = False
            current_time = self.get_current_timestamp()
            train_boxes = []
            
            for result in results:
                if result.boxes is None:
                    continue
                
                boxes = result.boxes.xyxy.cpu().numpy()
                confidences = result.boxes.conf.cpu().numpy()
                classes = result.boxes.cls.cpu().numpy().astype(int)
                
                if hasattr(result, 'names') and result.names:
                    class_names = result.names
                    
                    for box, conf, cls in zip(boxes, confidences, classes):
                        if cls < len(class_names):
                            class_name = class_names[cls].lower()
                            
                            train_keywords = ['train', 'locomotive', 'subway', 'metro', 'rail']
                            if any(keyword in class_name for keyword in train_keywords) and conf > self.train_detection_threshold:
                                train_detected = True
                                self.last_train_detection_time = current_time
                                x1, y1, x2, y2 = box
                                train_boxes.append({
                                    'bbox': [int(x1), int(y1), int(x2), int(y2)],
                                    'confidence': float(conf),
                                    'class_name': class_name
                                })
            
            if not train_detected and self.last_train_detection_time:
                time_since_last = (current_time - self.last_train_detection_time).total_seconds()
                if time_since_last > self.train_absence_timeout:
                    if self.train_present:
                        print(f"[TRAIN DETECTION] Train absent for {time_since_last:.1f}s - resuming person detection")
                    self.train_present = False
                    self.train_bboxes = []
                else:
                    train_detected = True
            
            if train_detected:
                if not self.train_present:
                    print("[TRAIN DETECTION] Train detected - pausing person detection")
                self.train_present = True
                if train_boxes:
                    self.train_bboxes = train_boxes
            else:
                self.train_bboxes = []
                
            return train_detected, train_boxes
            
        except Exception as e:
            print(f"[ERROR] Train detection failed: {e}")
            return False, []
    
    def draw_train_bboxes(self, frame):
        """Draw bounding boxes for detected trains"""
        for train in self.train_bboxes:
            x1, y1, x2, y2 = train['bbox']
            confidence = train['confidence']
            class_name = train['class_name']
            
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 3)
            
            label = f"TRAIN: {class_name} ({confidence:.2f})"
            label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2)[0]
            cv2.rectangle(frame, (x1, y1 - label_size[1] - 10), 
                         (x1 + label_size[0] + 10, y1), (255, 0, 0), -1)
            cv2.putText(frame, label, (x1 + 5, y1 - 5), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
        
        return frame
    
    def is_peak_hour(self, hour):
        """Check if the given hour is within peak hours"""
        for start, end in self.peak_hours:
            if start <= hour < end:
                return 1
        return 0
    
    def init_detection_log_csv(self):
        """Initialize detection log CSV file"""
        if not self.detection_log_csv.exists():
            with open(self.detection_log_csv, 'w', newline='') as f:
                writer = csv.writer(f)
                headers = [
                    'timestamp', 'day', 'hour', 'minute', 'day_of_week',
                    'peak_hour', 'passenger_count', 'train_detected', 'breach_type',
                    'lag_10min', 'lag_20min', 'lag_30min', 
                    'lag_1hr', 'lag_2hr', 'lag_3hr',
                    'rolling_mean_30min', 'rolling_std_30min',
                    'rolling_mean_1hr', 'rolling_std_1hr',
                    'rolling_max_1hr', 'rolling_min_1hr',
                    'rolling_mean_2hr', 'rolling_std_2hr',
                    'change_10min', 'change_30min', 'change_1hr',
                    'pct_change_10min', 'pct_change_30min', 'pct_change_1hr',
                    'momentum', 'trend_strength',
                    'volatility', 'position_in_range',
                    'hour_sin', 'hour_cos',
                    'minute_sin', 'minute_cos',
                    'dow_sin', 'dow_cos',
                    'is_morning_peak', 'is_evening_peak', 'is_peak_hour',
                    'is_night', 'is_business_hours', 'is_weekend',
                    'hour_x_rolling_mean', 'peak_x_lag'
                ]
                writer.writerow(headers)
                print(f"✅ CSV initialized with {len(headers)} columns")
    
    def calculate_features(self, passenger_count, timestamp):
        """Calculate all XGBoost features"""
        hour = timestamp.hour
        minute = timestamp.minute
        day_of_week = timestamp.weekday()
        
        history = list(self.passenger_count_history)
        features = {}
        
        # Lag features
        features['lag_10min'] = history[-2] if len(history) >= 2 else passenger_count
        features['lag_20min'] = history[-3] if len(history) >= 3 else passenger_count
        features['lag_30min'] = history[-4] if len(history) >= 4 else passenger_count
        features['lag_1hr'] = history[-7] if len(history) >= 7 else passenger_count
        features['lag_2hr'] = history[-13] if len(history) >= 13 else passenger_count
        features['lag_3hr'] = history[-19] if len(history) >= 19 else passenger_count
        
        # Rolling statistics
        if len(history) >= 3:
            recent_30min = history[-3:]
            features['rolling_mean_30min'] = np.mean(recent_30min)
            features['rolling_std_30min'] = np.std(recent_30min) if len(recent_30min) > 1 else 0
        else:
            features['rolling_mean_30min'] = passenger_count
            features['rolling_std_30min'] = 0
        
        if len(history) >= 6:
            recent_1hr = history[-6:]
            features['rolling_mean_1hr'] = np.mean(recent_1hr)
            features['rolling_std_1hr'] = np.std(recent_1hr)
            features['rolling_max_1hr'] = np.max(recent_1hr)
            features['rolling_min_1hr'] = np.min(recent_1hr)
        else:
            features['rolling_mean_1hr'] = passenger_count
            features['rolling_std_1hr'] = 0
            features['rolling_max_1hr'] = passenger_count
            features['rolling_min_1hr'] = passenger_count
        
        if len(history) >= 12:
            recent_2hr = history[-12:]
            features['rolling_mean_2hr'] = np.mean(recent_2hr)
            features['rolling_std_2hr'] = np.std(recent_2hr)
        else:
            features['rolling_mean_2hr'] = passenger_count
            features['rolling_std_2hr'] = 0
        
        # Change features
        features['change_10min'] = history[-1] - history[-2] if len(history) >= 2 else 0
        features['change_30min'] = history[-1] - history[-4] if len(history) >= 4 else 0
        features['change_1hr'] = history[-1] - history[-7] if len(history) >= 7 else 0
        
        # Percentage change
        features['pct_change_10min'] = (history[-1] - history[-2]) / history[-2] if len(history) >= 2 and history[-2] > 0 else 0
        features['pct_change_30min'] = (history[-1] - history[-4]) / history[-4] if len(history) >= 4 and history[-4] > 0 else 0
        features['pct_change_1hr'] = (history[-1] - history[-7]) / history[-7] if len(history) >= 7 and history[-7] > 0 else 0
        
        # Momentum & trend
        features['momentum'] = features['lag_10min'] - features['lag_1hr']
        features['trend_strength'] = features['rolling_mean_30min'] - features['rolling_mean_2hr']
        
        # Volatility
        features['volatility'] = features['rolling_max_1hr'] - features['rolling_min_1hr']
        range_val = features['volatility']
        features['position_in_range'] = (passenger_count - features['rolling_min_1hr']) / range_val if range_val > 0 else 0.5
        
        # Cyclical time features
        features['hour_sin'] = np.sin(2 * np.pi * hour / 24)
        features['hour_cos'] = np.cos(2 * np.pi * hour / 24)
        features['minute_sin'] = np.sin(2 * np.pi * minute / 60)
        features['minute_cos'] = np.cos(2 * np.pi * minute / 60)
        features['dow_sin'] = np.sin(2 * np.pi * day_of_week / 7)
        features['dow_cos'] = np.cos(2 * np.pi * day_of_week / 7)
        
        # Binary time features
        features['is_morning_peak'] = 1 if 6 <= hour <= 9 else 0
        features['is_evening_peak'] = 1 if 16 <= hour <= 19 else 0
        features['is_peak_hour'] = features['is_morning_peak'] or features['is_evening_peak']
        features['is_night'] = 1 if (hour >= 22 or hour <= 5) else 0
        features['is_business_hours'] = 1 if 9 <= hour <= 17 else 0
        features['is_weekend'] = 1 if day_of_week >= 5 else 0
        
        # Interaction features
        features['hour_x_rolling_mean'] = hour * features['rolling_mean_1hr']
        features['peak_x_lag'] = features['is_peak_hour'] * features['lag_10min']
        
        return features
    
    def log_detection(self, passenger_count, train_detected, breach_type, timestamp):
        """Log detection data to CSV"""
        if self.last_log_time is not None:
            time_since_last = (timestamp - self.last_log_time).total_seconds()
            if time_since_last < self.log_interval:
                return
        
        features = self.calculate_features(passenger_count, timestamp)
        
        day = timestamp.strftime('%A')
        hour = timestamp.hour
        minute = timestamp.minute
        day_of_week = timestamp.weekday()
        peak_hour = 1 if self.is_peak_hour(hour) else 0
        train_det_flag = 1 if train_detected else 0
        breach_type_str = breach_type if breach_type else ""
        
        with open(self.detection_log_csv, 'a', newline='') as f:
            writer = csv.writer(f)
            row = [
                timestamp.isoformat(), day, hour, minute, day_of_week,
                peak_hour, passenger_count, train_det_flag, breach_type_str,
                features['lag_10min'], features['lag_20min'], features['lag_30min'],
                features['lag_1hr'], features['lag_2hr'], features['lag_3hr'],
                features['rolling_mean_30min'], features['rolling_std_30min'],
                features['rolling_mean_1hr'], features['rolling_std_1hr'],
                features['rolling_max_1hr'], features['rolling_min_1hr'],
                features['rolling_mean_2hr'], features['rolling_std_2hr'],
                features['change_10min'], features['change_30min'], features['change_1hr'],
                features['pct_change_10min'], features['pct_change_30min'], features['pct_change_1hr'],
                features['momentum'], features['trend_strength'],
                features['volatility'], features['position_in_range'],
                features['hour_sin'], features['hour_cos'],
                features['minute_sin'], features['minute_cos'],
                features['dow_sin'], features['dow_cos'],
                features['is_morning_peak'], features['is_evening_peak'], features['is_peak_hour'],
                features['is_night'], features['is_business_hours'], features['is_weekend'],
                features['hour_x_rolling_mean'], features['peak_x_lag']
            ]
            writer.writerow(row)
        
        self.last_log_time = timestamp
    
    def get_current_timestamp(self):
        """Get current timestamp"""
        if self.timestamp_override is not None:
            if self.timestamp_offset is not None:
                elapsed = (datetime.now() - self.timestamp_offset).total_seconds()
                return self.timestamp_override + timedelta(seconds=elapsed)
            return self.timestamp_override
        return datetime.now()

    def set_timestamp_override(self, timestamp_str=None, reset=False):
        """Set a custom timestamp override"""
        if reset or timestamp_str is None:
            self.timestamp_override = None
            self.timestamp_offset = None
            return datetime.now()
        
        try:
            custom_time = datetime.fromisoformat(timestamp_str)
            self.timestamp_override = custom_time
            self.timestamp_offset = datetime.now()
            return custom_time
        except Exception as e:
            raise ValueError(f"Invalid timestamp format: {e}")
    
    def check_zone_breach_foot(self, x1, y1, x2, y2, camera_name="cam1"):
        """Check if a person's foot position is in danger or warning zone"""
        zones = self.zone_definitions.get(camera_name, self.zone_definitions["cam1"])
        
        foot_x = int((x1 + x2) / 2)
        foot_y = int(y2)
        
        point = Point(foot_x, foot_y)
        danger_polygon = Polygon(zones["danger"])
        warning_polygon = Polygon(zones["warning"])
        
        breach_type = None
        if danger_polygon.contains(point):
            breach_type = "danger"
        elif warning_polygon.contains(point):
            breach_type = "warning"
        
        return breach_type, (foot_x, foot_y)
    
    def process_frame(self, image, camera_name="cam1"):
        """Process a single frame with tracking and train detection"""
        train_detected, train_boxes = self.detect_train(image) 
        
        frame_breach_type = ""
        
        if self.train_present:
            current_time = self.get_current_timestamp()
            self.log_detection(0, True, "", current_time)
            return [], 0
        
        zones = self.zone_definitions.get(camera_name, self.zone_definitions["cam1"])
        zone_polygons = {z: Polygon(pts) for z, pts in zones.items()}

        results = self.model.predict(source=image, conf=0.25, save=False)

        detections = []
        det_array = []

        for result in results:
            if result.boxes is None:
                continue

            boxes = result.boxes.xyxy.cpu().numpy()
            confidences = result.boxes.conf.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy().astype(int)

            for box, conf, cls in zip(boxes, confidences, classes):
                if cls != 0:
                    continue

                x1, y1, x2, y2 = box[:4]
                boosted_conf = min(conf * 1.1, 1.0)
                det_array.append([x1, y1, x2, y2, boosted_conf])

        if len(det_array) > 0:
            det_array = np.array(det_array)
        else:
            det_array = np.empty((0, 5))

        tracked_objects = self.trackers[camera_name].update(det_array)

        frame_passengers = 0
        current_time = self.get_current_timestamp()

        for track in tracked_objects:
            x1, y1, x2, y2, track_id = track.astype(int)

            foot_x = int((x1 + x2) / 2)
            foot_y = int(y2)
            foot_point = Point(foot_x, foot_y)

            breach_type = None
            if zone_polygons["danger"].contains(foot_point):
                breach_type = "danger"
            elif zone_polygons["warning"].contains(foot_point):
                breach_type = "warning"
            
            if breach_type == "danger":
                frame_breach_type = "danger"
            elif breach_type == "warning" and frame_breach_type != "danger":
                frame_breach_type = "warning"

            person = self.person_histories[track_id]
            if person["first_seen"] is None:
                person["first_seen"] = current_time
                self.stats["unique_people"].add(track_id)

            person["last_seen"] = current_time
            person["positions"].append({
                "time": current_time.isoformat(),
                "bbox": [x1, y1, x2, y2],
                "foot_position": [foot_x, foot_y],
                "zone": breach_type or "safe"
            })

            if len(person["positions"]) > 100:
                person["positions"] = person["positions"][-100:]

            if breach_type:
                prev_positions = person["positions"][-5:-1] if len(person["positions"]) > 1 else []
                was_safe = all(p["zone"] == "safe" for p in prev_positions[-3:]) if prev_positions else True

                if was_safe:
                    person["breach_history"].append({
                        "time": current_time.isoformat(),
                        "type": breach_type,
                        "position": [foot_x, foot_y]
                    })
                    person["total_breaches"][breach_type] += 1

                    if breach_type == "danger":
                        self.stats["danger_breaches"] += 1
                    else:
                        self.stats["warning_breaches"] += 1

                    self.stats["breach_logs"].append({
                        "timestamp": current_time.isoformat(),
                        "zone": breach_type,
                        "position": [foot_x, foot_y],
                        "camera": camera_name,
                        "person_id": int(track_id)
                    })

            frame_passengers += 1
            self.stats["total_detections"] += 1

            confidence = 0.9
            if len(det_array) > 0:
                best_iou = 0
                best_conf = 0.9
                for det in det_array:
                    det_x1, det_y1, det_x2, det_y2, det_conf = det

                    xx1 = max(x1, det_x1)
                    yy1 = max(y1, det_y1)
                    xx2 = min(x2, det_x2)
                    yy2 = min(y2, det_y2)

                    w = max(0, xx2 - xx1)
                    h = max(0, yy2 - yy1)

                    if w > 0 and h > 0:
                        intersection = w * h
                        area1 = (x2 - x1) * (y2 - y1)
                        area2 = (det_x2 - det_x1) * (det_y2 - det_y1)
                        union = area1 + area2 - intersection
                        iou = intersection / union if union > 0 else 0

                        if iou > best_iou:
                            best_iou = iou
                            best_conf = float(det_conf)

                confidence = best_conf

            detection = {
                "x1": int(x1),
                "y1": int(y1),
                "x2": int(x2),
                "y2": int(y2),
                "confidence": confidence,
                "class": 0,
                "label": "person",
                "breach_type": breach_type,
                "center": [int((x1 + x2) / 2), int((y1 + y2) / 2)],
                "foot_position": [foot_x, foot_y],
                "track_id": int(track_id),
                "breach_count": person["total_breaches"],
                "time_in_zone": len([p for p in person["positions"][-10:] if p["zone"] == breach_type]) if breach_type else 0
            }
            detections.append(detection)
        
        self.log_detection(frame_passengers, False, frame_breach_type, current_time)
        
        return detections, frame_passengers
    
    def process_video_file(self, video_path, camera_name="cam1", save_annotated=True):
        """
        ✅ ENHANCED: Process video with real-time predictions
        """
        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS) or 30
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        
        # Reset everything for new video
        self.trackers[camera_name] = Sort(max_age=30, min_hits=3, iou_threshold=0.3)
        self.train_present = False
        self.last_train_detection_time = None
        self.train_bboxes = []
        self.passenger_count_history.clear()
        self.clear_video_predictions()  # ✅ Clear previous predictions
        
        zones = self.zone_definitions[camera_name]
        zone_polygons = {z: Polygon(pts) for z, pts in zones.items()}
        
        output_path = None
        if save_annotated:
            output_dir = "annotated"
            os.makedirs(output_dir, exist_ok=True)
            output_path = os.path.join(output_dir, os.path.basename(video_path))
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        
        frame_id = 0
        breach_log = []
        person_total = 0
        red_total = 0
        yellow_total = 0
        unique_people = set()
        train_frames = 0
        total_frames = 0
        
        print(f"[VIDEO PROCESSING] Starting with REAL-TIME PREDICTION enabled...")
        print(f"[VIDEO PROCESSING] Predictions will be made every {self.prediction_interval} seconds")
        print("="*60)
        
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            frame_id += 1
            total_frames += 1

            frame_time = frame_id / fps
            
            # Process frame with tracking and train detection
            detections, passenger_count = self.process_frame(frame, camera_name)
            
            # ✅ MAKE REAL-TIME PREDICTION
            prediction = self.make_video_prediction(
                passenger_count, 
                self.get_current_timestamp(), 
                frame_id
            )
            
            if self.train_present:
                train_frames += 1
            
            # Draw zones
            for zone, pts in zones.items():
                color = (0, 255, 0) if zone == "safe" else (0, 255, 255) if zone == "warning" else (0, 0, 255)
                pts_array = np.array(pts, np.int32)
                cv2.polylines(frame, [pts_array], isClosed=True, color=color, thickness=2)
            
            # Draw train bboxes if present
            if self.train_present and self.train_bboxes:
                frame = self.draw_train_bboxes(frame)
            
            # Train status indicator
            train_status_text = "TRAIN DETECTED - DETECTION PAUSED" if self.train_present else "PERSON DETECTION ACTIVE"
            train_status_color = (0, 0, 255) if self.train_present else (0, 255, 0)
            cv2.putText(frame, train_status_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, train_status_color, 2)
            
            # ✅ DRAW PREDICTION INFO ON VIDEO
            if prediction and not self.train_present:
                y_offset = 60
                
                # Current status
                current = prediction['current']
                current_text = f"Current: {current['count']} ({current['percentage']:.1f}%) {current['emoji']} {current['level']}"
                cv2.putText(frame, current_text, (10, y_offset), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
                
                # Predicted status
                y_offset += 30
                predicted = prediction['predicted']
                predicted_text = f"Predicted: {predicted['count']:.1f} ({predicted['percentage']:.1f}%) {predicted['emoji']} {predicted['level']}"
                
                # Color based on priority
                pred_color = (0, 255, 0) if predicted['priority'] <= 2 else \
                            (0, 255, 255) if predicted['priority'] == 3 else \
                            (0, 165, 255) if predicted['priority'] == 4 else (0, 0, 255)
                
                cv2.putText(frame, predicted_text, (10, y_offset), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, pred_color, 2)
                
                # Trend indicator
                y_offset += 30
                trend_symbol = "↑" if prediction['trend'] == "increasing" else \
                              "↓" if prediction['trend'] == "decreasing" else "→"
                trend_text = f"Trend: {trend_symbol} {prediction['trend']}"
                cv2.putText(frame, trend_text, (10, y_offset), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
                
                # Alert if action required
                if predicted['action_required']:
                    y_offset += 35
                    cv2.rectangle(frame, (5, y_offset - 25), (width - 5, y_offset + 10), (0, 0, 255), 2)
                    cv2.rectangle(frame, (7, y_offset - 23), (width - 7, y_offset + 8), (0, 0, 255), -1)
                    alert_text = "⚠️ ACTION REQUIRED - " + predicted['recommendation'][:50]
                    cv2.putText(frame, alert_text, (10, y_offset), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            
            # Draw person detections
            if not self.train_present:
                for det in detections:
                    x1, y1, x2, y2 = det["x1"], det["y1"], det["x2"], det["y2"]
                    track_id = det["track_id"]
                    breach_type = det["breach_type"]
                    foot_x, foot_y = det["foot_position"]

                    unique_people.add(track_id)
                    
                    color = (0, 255, 0)
                    label = f"Person #{track_id}"
                    
                    if breach_type == "danger":
                        color = (0, 0, 255)
                        label += " - DANGER"
                    elif breach_type == "warning":
                        color = (0, 255, 255)
                        label += " - WARNING"
                    
                    cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                    
                    label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)[0]
                    cv2.rectangle(frame, (x1, y1 - label_size[1] - 4), 
                                 (x1 + label_size[0], y1), color, -1)
                    cv2.putText(frame, label, (x1, y1 - 2), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
                    
                    cv2.circle(frame, (foot_x, foot_y), 5, color, -1)
                    cv2.line(frame, (foot_x - 10, foot_y), (foot_x + 10, foot_y), color, 2)
            
            # Frame statistics
            stats_text = f"Frame: {frame_id} | Train: {train_frames}/{total_frames} ({train_frames/total_frames*100:.1f}%)"
            cv2.putText(frame, stats_text, (10, height - 20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            
            person_total = len(unique_people)
            
            if save_annotated:
                out.write(frame)
            
            # Progress update
            if frame_id % 100 == 0:
                print(f"[PROGRESS] Frame {frame_id} | Passengers: {passenger_count} | Predictions made: {len(self.video_predictions)}")
        
        cap.release()
        if save_annotated:
            out.release()
        
        # Calculate breach totals
        for person_id, history in self.person_histories.items():
            red_total += history["total_breaches"]["danger"]
            yellow_total += history["total_breaches"]["warning"]
        
        train_percentage = (train_frames / total_frames * 100) if total_frames > 0 else 0
        
        print("="*60)
        print(f"[VIDEO PROCESSING] ✅ COMPLETED!")
        print(f"  Total frames: {total_frames}")
        print(f"  Unique passengers: {len(unique_people)}")
        print(f"  Predictions made: {len(self.video_predictions)}")
        print(f"  Train present: {train_frames} frames ({train_percentage:.1f}%)")
        print("="*60)
        
        # ✅ GENERATE PREDICTION SUMMARY
        prediction_summary = self.generate_prediction_summary()
        
        return {
            "total_passengers": person_total,
            "unique_passengers": len(unique_people),
            "breach_counts": {
                "danger": red_total,
                "warning": yellow_total
            },
            "breaches": breach_log,
            "annotated_video": output_path if save_annotated else None,
            "train_statistics": {
                "train_frames": train_frames,
                "total_frames": total_frames,
                "train_percentage": train_percentage
            },
            "predictions": {
                "total_predictions": len(self.video_predictions),
                "predictions_list": self.video_predictions,
                "summary": prediction_summary
            }
        }
    
    def generate_prediction_summary(self):
        """Generate a summary of all predictions made during video processing"""
        if len(self.video_predictions) == 0:
            return None
        
        # Analyze all predictions
        high_priority = [p for p in self.video_predictions if p['predicted']['priority'] >= 4]
        moderate_priority = [p for p in self.video_predictions if p['predicted']['priority'] == 3]
        
        # Find peak crowding
        peak_prediction = max(self.video_predictions, 
                            key=lambda x: x['predicted']['percentage'])
        
        # Find lowest crowding
        lowest_prediction = min(self.video_predictions, 
                               key=lambda x: x['predicted']['percentage'])
        
        # Calculate average predicted crowding
        avg_predicted = np.mean([p['predicted']['percentage'] for p in self.video_predictions])
        avg_current = np.mean([p['current']['percentage'] for p in self.video_predictions])
        
        # Count trend directions
        increasing_trends = sum(1 for p in self.video_predictions if p['trend'] == 'increasing')
        decreasing_trends = sum(1 for p in self.video_predictions if p['trend'] == 'decreasing')
        stable_trends = sum(1 for p in self.video_predictions if p['trend'] == 'stable')
        
        summary = {
            "total_predictions": len(self.video_predictions),
            "high_priority_periods": len(high_priority),
            "moderate_priority_periods": len(moderate_priority),
            "peak_crowding": {
                "frame": peak_prediction['frame_id'],
                "time": peak_prediction['video_time'],
                "current": peak_prediction['current']['percentage'],
                "predicted": peak_prediction['predicted']['percentage'],
                "level": peak_prediction['predicted']['level']
            },
            "lowest_crowding": {
                "frame": lowest_prediction['frame_id'],
                "time": lowest_prediction['video_time'],
                "current": lowest_prediction['current']['percentage'],
                "predicted": lowest_prediction['predicted']['percentage'],
                "level": lowest_prediction['predicted']['level']
            },
            "averages": {
                "current_percentage": round(avg_current, 2),
                "predicted_percentage": round(avg_predicted, 2)
            },
            "trends": {
                "increasing": increasing_trends,
                "decreasing": decreasing_trends,
                "stable": stable_trends
            },
            "alerts": {
                "overcrowding_warnings": sum(1 for p in self.video_predictions if 'safety_alert' in p),
                "action_required_periods": sum(1 for p in self.video_predictions if p['predicted']['action_required'])
            }
        }
        
        return summary
    
    def setup_routes(self):
        @self.app.route('/health', methods=['GET'])
        def health():
            gpu_info = {}
            if self.device == 'cuda':
                gpu_info = {
                    "gpu_name": torch.cuda.get_device_name(0),
                    "memory_allocated": f"{torch.cuda.memory_allocated(0) / 1024**2:.2f} MB",
                    "memory_reserved": f"{torch.cuda.memory_reserved(0) / 1024**2:.2f} MB",
                    "cuda_version": torch.version.cuda
                }
            
            return jsonify({
                "status": "running",
                "model_loaded": self.model is not None,
                "xgboost_loaded": self.xgboost_model is not None,
                "device": self.device,
                "gpu_info": gpu_info,
                "model_path": self.model_path,
                "train_present": self.train_present,
                "detection_active": not self.train_present,
                "timestamp": self.get_current_timestamp().isoformat(),
                "prediction_enabled": self.xgboost_model is not None,
                "predictions_made": len(self.video_predictions)
            })
        
        @self.app.route('/latest_prediction', methods=['GET'])
        def get_latest_prediction():
            """Get the most recent prediction from video processing"""
            latest = self.get_latest_prediction()
            if latest:
                return jsonify({
                    "success": True,
                    "prediction": latest
                })
            else:
                return jsonify({
                    "success": False,
                    "message": "No predictions available yet"
                })
        
        @self.app.route('/zones/<camera>', methods=['GET'])
        def get_zones(camera):
            """Get zone definitions for a specific camera"""
            try:
                if camera not in self.zone_definitions:
                    return jsonify({
                        "success": False,
                        "error": f"Camera {camera} not found"
                    }), 404

                zones = self.zone_definitions[camera]

                return jsonify({
                    "success": True,
                    "camera": camera,
                    "zones": zones,
                    "timestamp": datetime.now().isoformat()
                })
            except Exception as e:
                print(f"Error getting zones: {e}")
                return jsonify({
                    "success": False,
                    "error": str(e)
                }), 500
        
        @self.app.route('/all_predictions', methods=['GET'])
        def get_all_predictions():
            """Get all predictions made during current video"""
            return jsonify({
                "success": True,
                "total": len(self.video_predictions),
                "predictions": self.video_predictions,
                "summary": self.generate_prediction_summary()
            })
        
        @self.app.route('/predict_crowding', methods=['GET'])
        def get_crowding_prediction():
            """Get crowding prediction for current state"""
            prediction = self.predict_crowding()
            
            if prediction is None:
                return jsonify({
                    "success": False,
                    "error": "XGBoost model not loaded or insufficient data",
                    "message": "Train model first or wait for more data collection"
                }), 503
            
            return jsonify(prediction)
        
        @self.app.route('/detect', methods=['POST'])
        def detect():
            if self.model is None:
                return jsonify({"success": False, "error": "Model not loaded"}), 500
            
            try:
                file = request.files.get('image')
                camera_name = request.form.get('camera', 'cam1')
                
                if not file:
                    return jsonify({"success": False, "error": "No image provided"}), 400
                
                image_bytes = file.read()
                nparr = np.frombuffer(image_bytes, np.uint8)
                image = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
                
                if image is None:
                    return jsonify({"success": False, "error": "Invalid image"}), 400
                
                with torch.cuda.amp.autocast(enabled=(self.device == 'cuda')):
                    with torch.no_grad():
                        detections, passenger_count = self.process_frame(image, camera_name)
                
                # Get prediction
                crowding_prediction = self.predict_crowding(passenger_count=passenger_count)
                
                response = {
                    "success": True,
                    "detections": detections,
                    "count": len(detections),
                    "device": self.device,
                    "camera": camera_name,
                    "train_present": self.train_present,
                    "train_bboxes": self.train_bboxes,
                    "detection_active": not self.train_present
                }
                
                if crowding_prediction and crowding_prediction.get('success'):
                    response["crowding_prediction"] = crowding_prediction
                
                return jsonify(response)
                
            except Exception as e:
                print(f"Detection error: {e}")
                traceback.print_exc()
                return jsonify({"success": False, "error": str(e)}), 500
        
        @self.app.route('/process_video', methods=['POST'])
        def process_video():
            """Process video with real-time predictions"""
            try:
                file = request.files.get('video')
                camera_name = request.form.get('camera', 'cam1')
                save_annotated = request.form.get('save_annotated', 'true').lower() == 'true'
                
                if not file:
                    return jsonify({"success": False, "error": "No video provided"}), 400
                
                temp_video_path = os.path.join('temp', 'uploaded_video.mp4')
                os.makedirs('temp', exist_ok=True)
                file.save(temp_video_path)
                
                result = self.process_video_file(temp_video_path, camera_name, save_annotated)
                
                os.remove(temp_video_path)
                
                return jsonify({
                    "success": True,
                    "result": result
                })
                
            except Exception as e:
                print(f"Video processing error: {e}")
                traceback.print_exc()
                return jsonify({"success": False, "error": str(e)}), 500
        
        @self.app.route('/reset_trackers', methods=['POST'])
        def reset_trackers():
            try:
                data = request.json or {}
                camera = data.get('camera', 'all')
                reset_counter = data.get('reset_counter', True)
                reset_timestamp = data.get('reset_timestamp', False)

                if reset_counter:
                    KalmanBoxTracker.count = 0

                if camera == 'all':
                    for cam in self.trackers:
                        self.trackers[cam] = Sort(max_age=30, min_hits=3, iou_threshold=0.3)
                else:
                    if camera in self.trackers:
                        self.trackers[camera] = Sort(max_age=30, min_hits=3, iou_threshold=0.3)

                self.person_histories.clear()
                self.stats["unique_people"].clear()
                self.train_present = False
                self.last_train_detection_time = None
                self.train_bboxes = []
                self.passenger_count_history.clear()
                self.clear_video_predictions()
                
                if reset_timestamp:
                    self.set_timestamp_override(reset=True)

                return jsonify({
                    "success": True, 
                    "message": f"Trackers and predictions reset",
                    "id_counter": KalmanBoxTracker.count,
                    "timestamp_reset": reset_timestamp
                })
            except Exception as e:
                return jsonify({"success": False, "error": str(e)}), 500
        
        @self.app.route('/stats', methods=['GET'])
        def get_stats():
            return jsonify({
                "total_passengers": self.stats["total_detections"],
                "breach_counts": {
                    "danger": self.stats["danger_breaches"],
                    "warning": self.stats["warning_breaches"]
                },
                "breach_logs": self.stats["breach_logs"][-10:],
                "train_present": self.train_present,
                "detection_active": not self.train_present,
                "predictions_made": len(self.video_predictions)
            })
    
    def run(self, **kwargs):
        """Run the Flask server"""
        self.app.run(**kwargs)

# %%
# Start the server
if os.path.exists(MODEL_PATH):
    try:
        # Create and run the server
        server = SubwayDetectionServer(MODEL_PATH)

        server.set_timestamp_override("2025-08-14T05:00:00")
        print(f"✓ Custom timestamp set to: {server.get_current_timestamp()}")
        print("\n" + "="*50)
        print("🚀 Subway Detection Server is running!")
        print("="*50)
        print(f"✓ Model: best.pt")
        print(f"✓ Device: {server.device}")
        if server.device == 'cuda':
            print(f"✓ GPU: {torch.cuda.get_device_name(0)}")
        print(f"\nEndpoints:")
        print(f"  • Health check: http://localhost:5000/health")
        print(f"  • Detection: http://localhost:5000/detect")
        print(f"  • Statistics: http://localhost:5000/stats")
        print("\n⚠️  Press 'Interrupt' button or Kernel → Interrupt to stop")
        print("="*50 + "\n")
        
        # Run the server
        server.run(debug=True, host='0.0.0.0', port=5000, use_reloader=False)
        
    except KeyboardInterrupt:
        print("\n\n✓ Server stopped by user")
    except Exception as e:
        print(f"❌ Error starting server: {e}")
        import traceback
        traceback.print_exc()
else:
    print(f"❌ Cannot start server - model file not found at: {MODEL_PATH}")
# Out:
# ...
# ✅ XGBoost MODEL LOADED SUCCESSFULLY
# ...
#    Model: passenger_model.json
#    Features: 42
#    Max Capacity: 40
#    Model R² Score: 0.9997851848602295
#    Training Date: 2025-10-13
#    🎯 CROWDING PREDICTION: ENABLED
# ...
# ✅ CSV initialized with 47 columns
# Using device: cuda
# GPU: Quadro P1000
# CUDA version: 12.1
# Loading model from: assets/model/best.pt
#
# 0: 960x960 (no detections), 158.4ms
# Speed: 10.7ms preprocess, 158.4ms inference, 19.4ms postprocess per image at shape (1, 3, 960, 960)
# ✓ Model loaded successfully on cuda
# ✓ Custom timestamp set to: 2025-08-14 05:00:00
#
# ...
# 🚀 Subway Detection Server is running!
# ...
# ✓ Model: best.pt
# ✓ Device: cuda
# ✓ GPU: Quadro P1000
#
# Endpoints:
#   • Health check: http://localhost:5000/health
#   • Detection: http://localhost:5000/detect
#   • Statistics: http://localhost:5000/stats
#
# ⚠️  Press 'Interrupt' button or Kernel → Interrupt to stop
# ...
#
#  * Serving Flask app '__main__'
#  * Debug mode: on
# ...
